# %%
r1=1
r2=2
r3=3
r4=4
r5=5
r6=6
r7=7
r8=8
r67=(r6*r7)/(r6+r7)
r34=(r3*r4)/(r4+r3)
r267=r2+r67
 r2567=(r267*r5)/(r267+r5)
r125678=r1+r2567+r8
req=(r125678*r34)/(r125678+r34)
print(req)
# Out:
#   File "/tmp/ipython-input-3404023263.py", line 12
#     r2567=(r267*r5)/(r267+r5)
#     ^
# IndentationError: unexpected indent
