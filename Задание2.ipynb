# %% [markdown]
# #**`Пример использования Markdown 2.0`**
# #### Можно делать:
# 1.   Список
# 2.   Рисунок
# 3.   Таблицу
# 4.   Ссылку
#
# ##### *Пример рисунка:*
# ![image.png](data:image/png;base64,...)
#
# ##### Пример таблицы:
#
# Название точек   |Точка А  |Точка B
# -----------------|---------|--------
# Координаты точек |  (0;3)  |(-7;0.2)
# Координаты точек | (10;-2) |  (5;1)
#
# ##### *Пример ссылки:*
#
# [Ссылка на гайд по Markdown](https://colab.research.google.com/notebooks/markdown_guide.ipynb?hl=ru#scrollTo=Lhfnlq1Surtk)
